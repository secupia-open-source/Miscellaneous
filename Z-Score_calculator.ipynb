# %%
import csv
import scipy 
import numpy as np
from datetime import date
from datetime import time
import datetime

# %%
def outlier(log,value):
    
    hours=[]
    minutes=[]
    
    for timeval in log:
        time = timeval.strftime("%H:%M:%S")
        myhour,myminute,mysecond = time.split(':')
        #print(myhour)
        #print(myminute)
        #print(mysecond)
        h_arr.append(int(myhour))
        m_arr.append(int(myminute))

    mytime = value.strftime("%H:%M:%S")
    myhour,myminute,mysecond = mytime.split(':')
    print(myhour)
    print(myminute)
    print(mysecond)
    
    
#     csvfile = open('exitdata.csv', 'r') 
#     reader = csv.reader(csvfile)

#     h_arr = []
#     m_arr = []

#     count = 0
#     for row in reader:
#         if(count==0):
#             count+=1
#         else:
#             temp1,temp2 = str(row).split(':')
#             waste,temp1 = temp1.split('[')
#             waste,temp1 = temp1.split("'")
#             #print(temp1)

#             temp2,waste = temp2.split(']')
#             temp2,waste = temp2.split("'")
#             #print(temp2)

#             h_arr.append(int(temp1))
#             m_arr.append(int(temp2))

#     #print(h_arr)
#     #print(m_arr)

#     hours = np.asarray(h_arr)
#     minutes = np.asarray(m_arr)

#     hours = hours*60
#     #print(hours)
#     time = hours+minutes
#     #print(time)

#     time_mean = np.mean(np.asarray(time))
#     #print(time_mean)

#     time_std = np.std(np.asarray(time))
#     #print(time_std)

#     z_score = (entry-time_mean)/time_std

# %%
var1 = datetime.datetime.now()
var2 = datetime.datetime.now()
var3 = datetime.datetime.now()
var4 = datetime.datetime.now()
var5 = datetime.datetime.now()
var6 = datetime.datetime.now()
var7 = datetime.datetime.now()
var8 = datetime.datetime.now()
var9 = datetime.datetime.now()
var10 = datetime.datetime.now()

log = []
log.append(var1)
log.append(var2)
log.append(var3)
log.append(var4)
log.append(var5)
log.append(var6)
log.append(var7)
log.append(var8)
log.append(var9)


#print(log[0].time())

var11 = datetime.datetime.now()

outlier(log,var11)
# Out:
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
# 00
# 24
# 50
